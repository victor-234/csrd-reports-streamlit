# %%
import pandas as pd

# %%
df = pd.read_excel("SRN-CSRD_report_archive.xlsx", sheet_name="csrd")

# %%
df
# Out:
#      verified     company          isin  country publication date  \
# 0         yes  Netcompany  DK0060952919  Denmark       2025-01-29
# 1         yes        Tryg  DK0060636678  Denmark       2025-01-23
# 2         yes         DSV  DK0060079531  Denmark       2025-02-04
# 3         yes    Lundbeck  DK0061804697  Denmark       2025-02-04
# 4         yes      Vestas  DK0061539921  Denmark       2025-02-05
# ...       ...         ...           ...      ...              ...
# 2068      NaN         NaN           NaN      NaN              NaT
# 2069      NaN         NaN           NaN      NaN              NaT
# 2070      NaN         NaN           NaN      NaN              NaT
# 2071      NaN         NaN           NaN      NaN              NaT
# 2072      NaN         NaN           NaN      NaN              NaT
#
#       claim full \nCSRD   auditor  start PDF  end PDF  pages PDF  \
# 0                  True        EY       62.0    154.0       92.0
# 1                  True       PwC       53.0    131.0       78.0
# 2                  True       PwC       42.0     84.0       42.0
# 3                  True       PwC       59.0    144.0       85.0
# 4                  True  Deloitte       51.0    132.0       81.0
# ...                 ...       ...        ...      ...        ...
# 2068              False       NaN        NaN      NaN        NaN
# 2069              False       NaN        NaN      NaN        NaN
# 2070              False       NaN        NaN      NaN        NaN
# 2071              False       NaN        NaN      NaN        NaN
# 2072              False       NaN        NaN      NaN        NaN
#
#                                                    link  \
# 0        https://netcompany.com/investor/annual-report/
# 1     https://tryg.com/sites/tryg.com/files/2025-01/...
# 2     https://investor.dsv.com/static-files/d34d3dfc...
# 3     https://www.lundbeck.com/content/dam/lundbeck-...
# 4     https://www.vestas.com/content/dam/vestas-com/...
# ...                                                 ...
# 2068                                                NaN
# 2069                                                NaN
# 2070                                                NaN
# 2071                                                NaN
# 2072                                                NaN
#
#         SASB industry \n(SICS® Industries)
# 0                Internet Media & Services
# 1                                Insurance
# 2                  Air Freight & Logistics
# 3          Biotechnology & Pharmaceuticals
# 4     Wind Technology & Project Developers
# ...                                    ...
# 2068                                   NaN
# 2069                                   NaN
# 2070                                   NaN
# 2071                                   NaN
# 2072                                   NaN
#
# [2073 rows x 12 columns]

# %%
industry_lookup = pd.read_excel("SRN-CSRD_report_archive.xlsx", sheet_name="industries")

# %%
csrd_url = "https://docs.google.com/spreadsheets/d/1Nlyf8Yz_9Fst8rEmQc2IMc-DWLF1fpmBTB7n4FlZwxs/export?format=csv&gid=0"
industry_url = "https://docs.google.com/spreadsheets/d/1Nlyf8Yz_9Fst8rEmQc2IMc-DWLF1fpmBTB7n4FlZwxs/export?format=csv&gid=1695573594"

pd.read_csv(csrd_url)
# Out:
#      Find our new interactive dashboard here  Unnamed: 1    Unnamed: 2  \
# 0                                   verified     company          isin
# 1                                        yes  Netcompany  DK0060952919
# 2                                        yes        Tryg  DK0060636678
# 3                                        yes         DSV  DK0060079531
# 4                                        yes    Lundbeck  DK0061804697
# ...                                      ...         ...           ...
# 2062                                     NaN         NaN           NaN
# 2063                                     NaN         NaN           NaN
# 2064                                     NaN         NaN           NaN
# 2065                                     NaN         NaN           NaN
# 2066                                     NaN         NaN           NaN
#
#      Unnamed: 3        Unnamed: 4         Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0       country  publication date  claim full \nCSRD    auditor  start PDF
# 1       Denmark        29/01/2025               TRUE         EY         62
# 2       Denmark        23/01/2025               TRUE        PwC         53
# 3       Denmark        04/02/2025               TRUE        PwC         42
# 4       Denmark        04/02/2025               TRUE        PwC         59
# ...         ...               ...                ...        ...        ...
# 2062        NaN               NaN              FALSE        NaN        NaN
# 2063        NaN               NaN              FALSE        NaN        NaN
# 2064        NaN               NaN              FALSE        NaN        NaN
# 2065        NaN               NaN              FALSE        NaN        NaN
# 2066        NaN               NaN              FALSE        NaN        NaN
#
#      Unnamed: 8 Unnamed: 9                                        Unnamed: 10  \
# 0       end PDF  pages PDF                                               link
# 1           154         92     https://netcompany.com/investor/annual-report/
# 2           131         78  https://tryg.com/sites/tryg.com/files/2025-01/...
# 3            84         42  https://investor.dsv.com/static-files/d34d3dfc...
# 4           144         85  https://www.lundbeck.com/content/dam/lundbeck-...
# ...         ...        ...                                                ...
# 2062        NaN        NaN                                                NaN
# 2063        NaN        NaN                                                NaN
# 2064        NaN        NaN                                                NaN
# 2065        NaN        NaN                                                NaN
# 2066        NaN        NaN                                                NaN
#
#                              Unnamed: 11
# 0     SASB industry \n(SICS® Industries)
# 1              Internet Media & Services
# 2                              Insurance
# 3                Air Freight & Logistics
# 4        Biotechnology & Pharmaceuticals
# ...                                  ...
# 2062                                 NaN
# 2063                                 NaN
# 2064                                 NaN
# 2065                                 NaN
# 2066                                 NaN
#
# [2067 rows x 12 columns]

# %%
pd.read_csv( "https://docs.google.com/spreadsheets/d/1Nlyf8Yz_9Fst8rEmQc2IMc-DWLF1fpmBTB7n4FlZwxs/edit?gid=218767986#gid=218767986")
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
#
#                                            Unnamed: 3
# 0                                                 NaN
# 1                  Sustainability Reporting Navigator
# 2                                 CSRD Report Archive
# 3                                                 NaN
# 4   Welcome to the SRN CSRD Report Archive. On the...
# 5   to learn about and share annual reports prepar...
# 6                                                 NaN
# 7   In the csrd sheet, you find a list of CSRD-com...
# 8   we will approve them and mark those in gray. P...
# 9   but do not make any audit, verification, or as...
# 10                                                NaN
# 11  In the non-csrd (other) reports sheet, feel fr...
# 12  From time to time, we move non-compliant repor...
# 13                                                NaN
# 14  Join our newsletter to stay up to date for new...
# 15                                                NaN
# 16      https://sustainabilityreportingnavigator.com/

# %%
import requests

# %%
headers = {"Content-Type": "application/json"}
data = {
    "query": "What are the transition plans of these companies according to ESRS E1?",
    "year": 2024,
    "sector": "Biotechnology & Pharmaceuticals"
}

response = requests.post(
    "https://sunhat-api.onrender.com/sustainability-reports/query", 
    json=data, 
    headers=headers
    )

sorted(response.json(), key=lambda x: x["score"], reverse=True)
# Out:
# [{'id': '91d44676-31f9-4cef-b4fd-10da7b0ba347',
#   'page': 59,
#   'x1': 488.45,
#   'y1': 156.53,
#   'x2': 844.04,
#   'y2': 163.01,
#   'score': 0.5464016632318023,
#   'text': '| ⚫︎ | SBM-2 SBM-3 | Interests and views of stakeholders Material impacts, risks, and opportunities and their interaction with strategy and business model | 51; 62-63; 72 62-67; 70; 79- 80\n |  | IRO-1 | Description of the processes to identify and assess material impacts, risks, and opportunities | 68-70\n |  | IRO-2 | Disclosure requirements in ESRS covered by the undertaking’s Sustainability Statement | 64; 68-69\nE1\nClimate change\n | ⚫︎ | GOV-3 E1-1 | Integration of sustainability-related performance in incentive schemes Transition plan for climate change mitigation | 44 75-78\n |  | SBM-3 | Material impacts, risks and opportunities and their interaction with strategy and business model | 63; 65; 79-80\n |  | IRO-1 | Description of the processes to identify and assess material climate-related impacts, risks and opportunities | 79-80\n |  | E1-2 | Policies related to climate change mitigation and adaptation | 75\n |  | E1-3 | Actions and resources in relation to climate change policies | 76-77',
#   'link': 'https://sunhat.fra1.digitaloceanspaces.com/sustainability-reports/9382ad69-86ec-4bec-a2c0-8426775225d8.pdf'},
#  {'id': '8be4d93e-af22-460e-a83a-5b1ea00e6176',
#   'page': 138,
#   'x1': 63.84,
#   'y1': 124.46,
#   'x2': 846.52,
#   'y2': 137.42,
#   'score': 0.5457684723000895,
#   'text': 'ESRS E1-1 | 16 (g): Undertakings excluded from Paris- aligned Benchmarks |  | Article 449a; Regulation (EU) No 575/2013; Commission Implementing Regulation (EU) 2022/2453 Template 1: Banking book-Cli- mate Change transition risk: Credit quality of exposures by sector, emissions and residual maturity | Delegated Regulation (EU) 2020/1818, Article12.1 (d) to (g), and Article 12.2 |  | 75\nESRS E1-4 | 34: GHG emission reduction targets | Indicator number 4 Table #2 of Annex 1 | Article 449a Regulation (EU) No 575/2013; Commission Implementing Regulation (EU) 2022/2453 Template 3: Banking book – Cli- mate change transition risk: alignment metrics | Delegated Regulation (EU) 2020/1818, Article 6 |  | 82\nESRS E1-5 | 38: Energy consumption from fossil sources | disaggregated by sources (only high climate | impact sectors) | Indicator number 5 Table #1 and Indi- | cator n. 5 Table #2 of Annex 1 | 81\nESRS E1-5 | 37: Energy consumption and mix | Indicator number 5 Table #1 of Annex 1 |  |  |  | 81',
#   'link': 'https://sunhat.fra1.digitaloceanspaces.com/sustainability-reports/9382ad69-86ec-4bec-a2c0-8426775225d8.pdf'},
#  {'id': '0fdf8bc8-e372-4cb6-aafa-46cac4bf8de9',
#   'page': 215,
#   'x1': 487.25,
#   'y1': 311.83,
#   'x2': 900.7,
#   'y2': 341.71,
#   'score': 0.5016080886604868,
#   'text': 'Financial Statements > Management statement\nThe year 2024 marks the initial implementation of paragraph 99 a of the Danish Financial Statements Act concerning compliance with ESRS.\nAs such, more clear guidance and practice are anticipated in various areas, which are expected to be issued in the coming years.\nFurthermore, the sustainability statement in- cludes forward-looking statements based on dis- closed assumptions about events that may occur in the future and possible future actions by the Group.\nActual outcomes are likely to be different since antic- ipated events frequently do not occur as expected.',
#   'link': 'https://sunhat.fra1.digitaloceanspaces.com/sustainability-reports/9382ad69-86ec-4bec-a2c0-8426775225d8.pdf'},
#  {'id': '87d7f6c8-5ee1-4bdf-95cf-87dd7824d563',
#   'page': 139,
#   'x1': 63.84,
#   'y1': 86.42,
#   'x2': 865.12,
#   'y2': 91.94,
#   'score': 0.49954935905632336,
#   'text': 'List of appendices\nDisclosure Requirement | Data point | SFDR reference | Pillar 3 reference | EU climate law reference | Page | Benchmark regulation reference\n--- | --- | --- | --- | --- | --- | ---\nbook – Climate change transition risk: Credit quality of ex- posures by sector, emissions and residual maturity\nESRS E1-6 | 53 to 55: Gross GHG emissions intensity | Indicators number 3 Table #1 of An- nex 1 | Article 449a; Regulation (EU) No 575/2013; Commission Im- plementing Regulation (EU) 2022/2453 Template 3: Banking book – Climate change transition risk: alignment metrics |  |  | Delegated Regulation (EU) 2020/1818, Article 8(1) 82-84\nESRS E1-7 | 56: GHG removals and carbon credits |  |  | Regulation (EU) 2021/1119, Article 2(1) |  | N/A\nESRS E1-9 | 66: Exposure of the benchmark portfolio to cli- mate-related physical risks |  |  |  |  | Delegated Regulation (EU) 2020/1818, Annex II Delegated Regulation (EU) 2020/1816, Annex II N/A',
#   'link': 'https://sunhat.fra1.digitaloceanspaces.com/sustainability-reports/9382ad69-86ec-4bec-a2c0-8426775225d8.pdf'},
#  {'id': '66dd6db1-672b-4559-84f6-1696a6890851',
#   'page': 17,
#   'x1': 58.68,
#   'y1': 514.68,
#   'x2': 434.48,
#   'y2': 520.68,
#   'score': 0.4993598163509487,
#   'text': 'Annual Report 2024 > Impacting patients, people, and society > Investing to grow > Business model and value chain > We ensure positive outcomes to people and societies\n1 ESRS 2 SBM-1, paragraph 42(a).\n2 ESRS 2 SBM-1, paragraph 42(b).\n3 ESRS 2 SBM-1, paragraph 42(c).\n*Subject to limited assurance.',
#   'link': 'https://sunhat.fra1.digitaloceanspaces.com/sustainability-reports/9382ad69-86ec-4bec-a2c0-8426775225d8.pdf'},
#  {'id': 'eb3ea947-4303-4df8-a67e-2be74169b0aa',
#   'page': 98,
#   'x1': 312.5,
#   'y1': 154.25,
#   'x2': 548.3299999999999,
#   'y2': 160.25,
#   'score': 0.49543084190580333,
#   'text': 'Of which transitional | - | 0 | 0% | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | -\nA.2 Taxonomy-eligible but not environmentally sustainable activities (not taxonomy-aligned activities)\nManufacture of medicinal products | PPC 1.2 | 24 | 1% | N/EL | N/EL | N/EL | EL | N/EL | N/EL | - | - | - | - | - | - | - | 0.4%1 | - | -\nTransport by motorbikes, passenger cars and light commercial vehicles | CCM 6.5 | 201 | 5% | EL | N/EL | N/EL | N/EL | N/EL | N/EL | - | - | - | - | - | - | - | 6.1%1 | - | -\nRenovation of existing buildings | CCM 7.2 | 12 | 0% | EL | N/EL | N/EL | N/EL | N/EL | N/EL | - | - | - | - | - | - | - | 0.2%1 | - | -\nOPEX of Taxonomy-eligible but not environ- mentally sustainable activities (not taxonomy- aligned activities) (A.2) |  | 237 | 6% |  |  |  |  |  |  |  |  |  |  |  |  |  | 6.7%1 |  | \nOPEX of taxonomy-eligible activities (A.1 + A.2) |  | 237 | 6% |  |  |  |  |  |  |  |  |  |  |  |  |  | 6.7%1 |  |',
#   'link': 'https://sunhat.fra1.digitaloceanspaces.com/sustainability-reports/9382ad69-86ec-4bec-a2c0-8426775225d8.pdf'},
#  {'id': 'cb5e51e7-6528-4965-b1a5-ae7bd0e61c39',
#   'page': 99,
#   'x1': 312.5,
#   'y1': 154.25,
#   'x2': 548.3299999999999,
#   'y2': 160.25,
#   'score': 0.49424895575631544,
#   'text': 'Of which transitional | - | 0 | 0% | - | - | - | - | - | - | - | - | - | - | - | - | - | - | - | -\nA.2 Taxonomy-eligible but not environmentally sustainable activities (not taxonomy-aligned activities)\nManufacture of medicinal products | PPC 1.2 | 16,645 | 98% | N/EL | N/EL | N/EL | EL | N/EL | N/EL | - | - | - | - | - | - | - | 20% | - | -\nConstruction of new buildings | CCM 7.1 | 190 | 1% | EL | N/EL | N/EL | N/EL | N/EL | N/EL |  |  |  |  |  |  |  | 0% |  | \nRenovation of existing buildings | CCM 7.2 | 70 | 0% | EL | N/EL | N/EL | N/EL | N/EL | N/EL | - | - | - | - | - | - | - | 5% | - | -\nTransport by motorbikes, passenger cars and light commercial vehicles | CCM 6.5 | 2 | 0% | EL | N/EL | N/EL | N/EL | N/EL | N/EL | - | - | - | - | - | - | - | 2% | - | -\nCAPEX of taxonomy-eligible but not environ- mentally sustainable activities (not taxon- omy-aligned activities) (A.2) |  | 16,907 | 99% | - | - | - | - | - | - | - | - | - | - | - | - | - | 27% | - | -',
#   'link': 'https://sunhat.fra1.digitaloceanspaces.com/sustainability-reports/9382ad69-86ec-4bec-a2c0-8426775225d8.pdf'},
#  {'id': '6353057f-aa3d-4bae-bb9c-205f63e3a05b',
#   'page': 77,
#   'x1': 70.68,
#   'y1': 195.53,
#   'x2': 248.95,
#   'y2': 227.09,
#   'score': 0.4855357715168145,
#   'text': 'Environment > Towards zero emissions > Targets > In the beginning of 2024, Lundbeck had two 1.5°C\nthe ESRS requirements2, an additional set of target values covering the period 2019-2030 was defined (see E1-6 table, page 82).',
#   'link': 'https://sunhat.fra1.digitaloceanspaces.com/sustainability-reports/9382ad69-86ec-4bec-a2c0-8426775225d8.pdf'},
#  {'id': 'ff88ef56-cb71-4544-a9d0-c4dbc2e00ac3',
#   'page': 43,
#   'x1': 59.52,
#   'y1': 492.96,
#   'x2': 528.46,
#   'y2': 498.96,
#   'score': 0.4850989273249542,
#   'text': 'Annual Report 2024 > Governance framework > Executive Management2\n1 ESRS 2, GOV-3 paragraph 29, 29(c), and 29(e).\n2 ESRS 2, GOV-1 paragraph 20(a), 21 (a) and 22 (c).\n3 ESRS 2, GOV-3 paragraph 29 (a), (b), (c) and (d), and ESRS E1 GOV-3.',
#   'link': 'https://sunhat.fra1.digitaloceanspaces.com/sustainability-reports/9382ad69-86ec-4bec-a2c0-8426775225d8.pdf'},
#  {'id': 'bb354474-e5cc-405d-a91b-aa121a37d2d7',
#   'page': 59,
#   'x1': 77.16,
#   'y1': 211.13,
#   'x2': 438.38,
#   'y2': 218.69,
#   'score': 0.4850743123844685,
#   'text': 'General disclosures > Guide to the Sustainability Statement\nThe Sustainability Statement is part of the Management Review and comprises four key reporting areas:\n• General information (ESRS 2)\n• Environmental information (ESRS E1, E2, and E5)\n• Social information (ESRS S1, S2, and S4)\n• Governance information (ESRS G1)',
#   'link': 'https://sunhat.fra1.digitaloceanspaces.com/sustainability-reports/9382ad69-86ec-4bec-a2c0-8426775225d8.pdf'}]
